# %%
def is_abecadarian(word):
    previous = word[0]
    for letter in word:
        if letter < previous:
            return False
        previous = letter
    return True

# %%
x=is_abecadarian("Manish")
print(x)
# Out:
# False
