# %%
x = []

# %%
x.append(5)

# %%
print(x)
# Out:
# [5]

# %% [markdown]
# ## First jupyter notebook class

# %% [markdown]
# ![Annotation%202020-06-21%20232433.jpg](attachment:Annotation%202020-06-21%20232433.jpg)
